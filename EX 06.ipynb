# %% [markdown]
# # EXP NO 6: Edge-Detection Using OpenCV
# ### NAME: DINESH R
# ### REG NO: 212224240037

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\\Users\\admin\\Downloads\\dolphin.png")  # replace with your path
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=5)
sobel = cv2.magnitude(sobel_x, sobel_y)

# %%
prewitt_x = np.array([[1, 0, -1],
                      [1, 0, -1],
                      [1, 0, -1]])

prewitt_y = np.array([[1, 1, 1],
                      [0, 0, 0],
                      [-1, -1, -1]])

# %%
prewitt_x_edge = cv2.filter2D(gray, -1, prewitt_x)
prewitt_y_edge = cv2.filter2D(gray, -1, prewitt_y)
prewitt = cv2.magnitude(prewitt_x_edge.astype(np.float32),
                        prewitt_y_edge.astype(np.float32))

# %%
roberts_x = np.array([[1, 0],
                      [0, -1]])

roberts_y = np.array([[0, 1],
                      [-1, 0]])

# %%
roberts_x_edge = cv2.filter2D(gray, -1, roberts_x)
roberts_y_edge = cv2.filter2D(gray, -1, roberts_y)
roberts = cv2.magnitude(roberts_x_edge.astype(np.float32),
                        roberts_y_edge.astype(np.float32))

# %%
laplacian = cv2.Laplacian(gray, cv2.CV_64F)

# %%
canny = cv2.Canny(gray, 50, 150)

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

print("DINESH R")
print("212224240037")

plt.title("Original")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
plt.subplot(2, 3, 2)
plt.imshow(sobel, cmap='gray')
print("DINESH R ")
print("212224240037")
plt.title("Sobel")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
plt.subplot(2, 3, 3)
plt.imshow(prewitt, cmap='gray')
print("DINESH R")
print("212224240037")
plt.title("Prewitt")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
plt.subplot(2, 3, 4)
plt.imshow(roberts, cmap='gray')
print("DINESH R")
print("212224240037")
plt.title("Roberts")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
plt.subplot(2, 3, 5)
plt.imshow(laplacian, cmap='gray')
print("DINESH R")
print("212224240037")
plt.title("Laplacian")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
plt.subplot(2, 3, 6)
plt.imshow(canny, cmap='gray')
print("DINESH R")
print("212224240037")
plt.title("Canny")
plt.axis("off")
# Out:
# DINESH R
# 212224240037
# (np.float64(-0.5), np.float64(425.5), np.float64(325.5), np.float64(-0.5))

# %%
print("DINESH R")
print("212224240037")
plt.tight_layout()
plt.show()
# Out:
# DINESH R
# 212224240037
